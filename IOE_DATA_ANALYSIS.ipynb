# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df=pd.read_excel(r"C://Users//shrikant padhy//Desktop//eshop.xlsx")

# %%
df
# Out:
#     ID     Name Classification          RFID   Price  Available Quantity  \
# 0    1  Samsung         Mobile  17AS235ASD12   25000                  23
# 1    2  Samsung             TV  SF43SD34SAD5   45000                   5
# 2    3  Samsung         Fridge  451SGAD124AF   40000                   7
# 3    4  Samsung        Display  5DAKC1235BDA   15000                  43
# 4    5       MI         Mobile  DF876ASD52SD   13000                  23
# 5    6       MI             TV  L324KL2SD80A   24000                  14
# 6    7       MI         Laptop  5SIHSDJ7342D   40000                  32
# 7    8       MI        Display   S0DS87SD12S   12000                  18
# 8    9  Oneplus         Mobile  87SGK3217SG5   50000                  21
# 9   10  Oneplus             TV  SK971HSKT47S   46000                   4
# 10  11  Oneplus      Headphone  KHR268DSKJ47    9000                  14
# 11  12  Oneplus    Smart Watch  2NO5KS790S25   16000                   8
# ...

# %%
df1=df.groupby(['Name'])[['Actual Profit','Sold Quantity']].sum()

# %%
df1
# Out:
#          Actual Profit  Sold Quantity
# Name
# Apple           8570.0              8
# Jio               60.0              3
# MI              2294.0             55
# Nokia            743.0              9
# Oneplus         4475.0             17
# Oppo             195.0             14
# Samsung         2995.0             62
# Vivo             642.0             29

# %%
df2=df.groupby(['Name'])[['Available Quantity','Total Quantity']].sum()

# %%
df2
# Out:
#          Available Quantity  Total Quantity
# Name
# Apple                    15              23
# Jio                       7              10
# MI                       87             142
# Nokia                    40              49
# Oneplus                  47              64
# Oppo                     21              35
# Samsung                  78             140
# Vivo                     50              79

# %%
df2['sold']=df2['Total Quantity']-df2['Available Quantity']

# %%
df2
# Out:
#          Available Quantity  Total Quantity  sold
# Name
# Apple                    15              23     8
# Jio                       7              10     3
# MI                       87             142    55
# Nokia                    40              49     9
# Oneplus                  47              64    17
# Oppo                     21              35    14
# Samsung                  78             140    62
# Vivo                     50              79    29

# %%
df3=pd.merge(df1,df2,on='Name')

# %%
df3
# Out:
#          Actual Profit  Sold Quantity  Available Quantity  Total Quantity  \
# Name
# Apple           8570.0              8                  15              23
# Jio               60.0              3                   7              10
# MI              2294.0             55                  87             142
# Nokia            743.0              9                  40              49
# Oneplus         4475.0             17                  47              64
# Oppo             195.0             14                  21              35
# Samsung         2995.0             62                  78             140
# Vivo             642.0             29                  50              79
#
#          sold
# Name
# Apple       8
# Jio         3
# MI         55
# Nokia       9
# Oneplus    17
# Oppo       14
# Samsung    62
# Vivo       29

# %%
#plot bar graph

# %%
df3.describe()
# Out:
#        Actual Profit  Sold Quantity  Available Quantity  Total Quantity  \
# count       8.000000       8.000000            8.000000        8.000000
# mean     2496.750000      24.625000           43.125000       67.750000
# std      2899.229935      22.353891           28.782125       50.193198
# min        60.000000       3.000000            7.000000       10.000000
# 25%       530.250000       8.750000           19.500000       32.000000
# 50%      1518.500000      15.500000           43.500000       56.500000
# 75%      3365.000000      35.500000           57.000000       94.250000
# max      8570.000000      62.000000           87.000000      142.000000
#
#             sold
# count   8.000000
# mean   24.625000
# std    22.353891
# min     3.000000
# 25%     8.750000
# 50%    15.500000
# 75%    35.500000
# max    62.000000

# %%
df3.plot.bar()
# Out:
# <AxesSubplot:xlabel='Name'>

# %%
#bar plot for Actual Profit

# %%
df4=df3

# %%
df5=df4.drop(['Sold Quantity','Available Quantity','Total Quantity','sold'],axis=1)

# %%
df5.plot.bar()
# Out:
# <AxesSubplot:xlabel='Name'>

# %%
#bar graph for Sold Items

# %%
df6=df3
df6
# Out:
#          Actual Profit  Sold Quantity  Available Quantity  Total Quantity  \
# Name
# Apple           8570.0              8                  15              23
# Jio               60.0              3                   7              10
# MI              2294.0             55                  87             142
# Nokia            743.0              9                  40              49
# Oneplus         4475.0             17                  47              64
# Oppo             195.0             14                  21              35
# Samsung         2995.0             62                  78             140
# Vivo             642.0             29                  50              79
#
#          sold
# Name
# Apple       8
# Jio         3
# MI         55
# Nokia       9
# Oneplus    17
# Oppo       14
# Samsung    62
# Vivo       29

# %%
df7=df3.drop(['Actual Profit','Available Quantity','Total Quantity','sold'],axis=1)

# %%
df7.plot.bar()
# Out:
# <AxesSubplot:xlabel='Name'>

# %%
df8=df3.drop(['Actual Profit','Sold Quantity','Total Quantity','Sold Quantity'],axis=1)

# %%
df8.plot.bar()
# Out:
# <AxesSubplot:xlabel='Name'>

# %%
df9=df.groupby(['Name','Classification'])['Actual Profit','Available Quantity','Total Quantity','Sold Quantity'].sum()
# Out:
# c:\users\shrikant padhy\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
df9
# Out:
#                         Actual Profit  Available Quantity  Total Quantity  \
# Name    Classification
# Apple   Laptop                 6360.0                   4               9
#         Mobile                 2210.0                  11              14
# Jio     Mobile                   60.0                   7              10
# MI      Display                 636.0                  18              24
#         Laptop                  480.0                  32              46
#         Mobile                  338.0                  23              37
#         TV                      840.0                  14              35
# Nokia   Display                  99.0                  24              29
#         Mobile                  644.0                  16              20
# Oneplus Headphone                63.0                  14              21
#         Mobile                 1350.0                  21              23
# ...

# %%
df9.plot.bar(figsize=(15,15))
# Out:
# <AxesSubplot:xlabel='Name,Classification'>

# %%
df9.plot.pie(subplots=True,figsize=(12,18))
# Out:
# c:\users\shrikant padhy\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_matplotlib\tools.py:331: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# array([<AxesSubplot:ylabel='Actual Profit'>,
#        <AxesSubplot:ylabel='Available Quantity'>,
#        <AxesSubplot:ylabel='Total Quantity'>,
#        <AxesSubplot:ylabel='Sold Quantity'>], dtype=object)
